# %%
from PCA_GeneData_fun import PCA_fun

# PCA_fun has 3 arguments
# genedata, metadata and no of features(if features are more and computational power is less
# then it can stuck the system as in my case, hence added this argument)
# no. of features defaults to 5000

# when going with default no. of features
PCA_fun('Assignment-2_gene_data- (2) (1) (1).csv', 'Assignment-2 Meta data sheet (2) (1) (1) (1).csv')

# when going with manual no. of features
#PCA_fun('Assignment-2_gene_data- (2) (1) (1).csv', 'Assignment-2 Meta data sheet (2) (1) (1) (1).csv', no_of_features = 7000)

# when going with all the features
#PCA_fun('Assignment-2_gene_data- (2) (1) (1).csv', 'Assignment-2 Meta data sheet (2) (1) (1) (1).csv', no_of_features = 'all')
# Out:
# /home/monu/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2856: DtypeWarning: Columns (3,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# /home/monu/anaconda3/envs/tensorflow/lib/python3.5/site-packages/numpy/core/numeric.py:544: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
